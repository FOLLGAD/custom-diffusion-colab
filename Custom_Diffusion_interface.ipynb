# %% [markdown]
# <a href="https://colab.research.google.com/github/FOLLGAD/custom-diffusion-colab/blob/main/Custom_Diffusion_interface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://huggingface.co/spaces/nupurkmr9/custom-diffusion
# !cd custom-diffusion && pip install -r requirements.txt
# Out:
# Cloning into 'custom-diffusion'...
# remote: Enumerating objects: 165, done.
# remote: Counting objects: 100% (150/150), done.
# remote: Compressing objects: 100% (149/149), done.
# remote: Total 165 (delta 82), reused 0 (delta 0), pack-reused 15
# Receiving objects: 100% (165/165), 35.94 KiB | 200.00 KiB/s, done.
# Resolving deltas: 100% (82/82), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 191 kB 4.1 MB/s
# ...
#      |████████████████████████████████| 62.5 MB 1.4 MB/s
# ...
#      |████████████████████████████████| 503 kB 93.4 MB/s
# ...
#      |████████████████████████████████| 53 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 3.2 MB 59.4 MB/s
# ...
#      |████████████████████████████████| 5.8 MB 27.7 MB/s
# ...
#      |████████████████████████████████| 18.3 MB 81.5 MB/s
# ...
#      |████████████████████████████████| 92.2 MB 31 kB/s
# ...
#      |████████████████████████████████| 351 kB 105.1 MB/s
# ...

# %%
# !pip install -Uqq gradio
# Out:
#      |████████████████████████████████| 13.8 MB 4.1 MB/s
#      |████████████████████████████████| 84 kB 2.6 MB/s
#      |████████████████████████████████| 2.3 MB 71.6 MB/s
#      |████████████████████████████████| 106 kB 76.3 MB/s
#      |████████████████████████████████| 84 kB 4.1 MB/s
#      |████████████████████████████████| 278 kB 60.7 MB/s
#      |████████████████████████████████| 55 kB 4.1 MB/s
#      |████████████████████████████████| 56 kB 5.0 MB/s
#      |████████████████████████████████| 64 kB 3.3 MB/s
#      |████████████████████████████████| 80 kB 10.1 MB/s
#      |████████████████████████████████| 69 kB 9.0 MB/s
#      |████████████████████████████████| 58 kB 6.4 MB/s
#      |████████████████████████████████| 50 kB 7.1 MB/s
# ...

# %%
# !cd custom-diffusion && python app.py
# Out:
# /usr/local/lib/python3.8/dist-packages/xformers/_C.so: undefined symbol: _ZNK3c104impl13OperatorEntry20reportSignatureErrorENS0_12CppSignatureE
# WARNING:root:WARNING: /usr/local/lib/python3.8/dist-packages/xformers/_C.so: undefined symbol: _ZNK3c104impl13OperatorEntry20reportSignatureErrorENS0_12CppSignatureE
# Need to compile C++ extensions to get sparse attention suport. Please run python setup.py build develop
# fatal: destination path 'custom-diffusion' already exists and is not an empty directory.
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://b82d7f9c-b4bf-497a.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# ...
